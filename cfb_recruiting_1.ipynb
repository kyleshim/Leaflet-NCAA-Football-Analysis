# %%
pip install cfbd
# Out:
# Collecting cfbd
#   Downloading cfbd-4.1.8-py3-none-any.whl (300 kB)
#      |████████████████████████████████| 300 kB 7.6 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.1 in ./opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from cfbd) (2.8.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from cfbd) (2020.6.20)
# Requirement already satisfied: six>=1.10 in ./opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from cfbd) (1.15.0)
# Requirement already satisfied: urllib3>=1.23 in ./opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from cfbd) (1.26.6)
# Installing collected packages: cfbd
# Successfully installed cfbd-4.1.8
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import os
from pprint import pprint
import cfbd
import json

# %%
# Save config information.
url = "https://api.collegefootballdata.com/teams/fbs"

# Build partial query URL
#response = requests.get(url).json()

# %%
configuration = cfbd.Configuration()
configuration.api_key['Authorization'] = '2sina0dm1CRBFSLRL91WQEFQQuY+JWy5tOMOyvCkiE++gayYwQEHNI6aXMsRy4Mi'
configuration.api_key_prefix['Authorization'] = 'Bearer'

# %%
# Recruiting Players Call
#api_recruiting = cfbd.RecruitingApi(cfbd.ApiClient(configuration))
#recruiting_2020 = api_recruiting.get_recruiting_players(year=2020)

# %%
# Games Call
#api_games = cfbd.GamesApi(cfbd.ApiClient(configuration))
#games_2020 = api_games.get_games(year=2020)

# %%
# Teams Call
api_teams = cfbd.TeamsApi(cfbd.ApiClient(configuration))
teams = api_teams.get_teams()

# %%
year = 2000
years = []
for i in range(22):
    current_year = year+i
    years.append(current_year)

# %%
years
# Out:
# [2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021]

# %%
# Recruiting Players Call
recruit_db = []
for current in years: 
    api_recruiting = cfbd.RecruitingApi(cfbd.ApiClient(configuration))
    recruiting = api_recruiting.get_recruiting_players(year=current)
    recruit_db.append(recruiting)

# %%
#len(recruiting_2020)
# Out:
# 4307

# %%
pprint(recruiting_2020[0])
# Out:
# {'athlete_id': 4428988,
#  'city': 'Damascus',
#  'committed_to': 'Clemson',
#  'country': 'USA',
#  'height': 77.0,
#  'hometown_info': {'fipsCode': '24031',
#                    'latitude': '39.2884381',
#                    'longitude': '-77.2038717'},
#  'id': 61569,
#  'name': 'Bryan Bresee',
#  'position': 'DT',
#  'ranking': 1,
#  'rating': 0.9995,
#  'recruit_type': 'HighSchool',
#  'school': 'Damascus',
#  'stars': 5,
#  'state_province': 'MD',
#  'weight': 290,
#  'year': 2020}

# %%
recruiting_df = pd.DataFrame()
for recruits in recruit_db:
    
    recruit_df = pd.DataFrame().from_records([
        dict(
            p_id=recruit.id,
            name=recruit.name,
            rating=recruit.rating,
            stars=recruit.stars,
            position=recruit.position,
            college=recruit.committed_to,
            player_lat=recruit.hometown_info['latitude'],
            player_lon=recruit.hometown_info['longitude'],
            state=recruit.state_province,
            country=recruit.country,
            year=recruit.year)
        for recruit in recruits])
#    recruit_df = recruit_df.set_index('p_id')
#    if recruit.state_province is not None and len(c.state_province) == 2 and c.state_province != 'AS' and c.state_province != 'QC' and c.state_province != 'HI'])
    recruiting_df = recruiting_df.append(recruit_df)
#    print(recruit_df)
#    print(recruiting_df)
recruiting_df
# Out:
#        p_id              name  rating  stars position           college  \
# 0         1     D.J. Williams  0.9998      5      ILB             Miami
# 1         2      Brock Berlin  0.9998      5      PRO           Florida
# 2         3    Charles Rogers  0.9988      5       WR    Michigan State
# 3         4    Travis Johnson  0.9982      5      SDE     Florida State
# 4         5    Marcus Houston  0.9980      5       RB          Colorado
# ...     ...               ...     ...    ...      ...               ...
# 2732  74091  Britton Williams  0.7530      2        K  Georgia Southern
# 2733  75815       Zach Zoglio  0.7530      2       LS  Eastern Michigan
# 2734  75816     Tanner Luther  0.7530      2        K  Eastern Michigan
# 2735  74092   Jabril Williams  0.7491      2      ATH              Army
# 2736  75361   Elisha Cummings  0.7441      2       RB             Idaho
#
#       player_lat    player_lon state country  year
# 0     37.9768525  -122.0335624    CA     USA  2000
# 1     32.5221828   -93.7651944    LA     USA  2000
# 2     43.4200387   -83.9490365    MI     USA  2000
# 3     34.1508718  -118.4489865    CA     USA  2000
# 4     39.7392364  -104.9848623    CO     USA  2000
# ...          ...           ...   ...     ...   ...
# 2732  31.9382652   -81.3034433    GA     USA  2021
# 2733  39.1014537   -84.5124602    OH     USA  2021
# 2734  39.9405903   -77.6598624    PA     USA  2021
# 2735  41.5263603   -88.0840212    IL     USA  2021
# 2736   31.549333   -97.1466695    TX     USA  2021
#
# [60073 rows x 11 columns]

# %%
len(recruiting_df)
# Out:
# 60073

# %%
len(games_2020)
# Out:
# 542

# %%
pprint(games_2020[0])
# Out:
# {'attendance': None,
#  'away_conference': None,
#  'away_id': 2110,
#  'away_line_scores': [7, 14, 0, 14],
#  'away_points': 35,
#  'away_post_win_prob': 0.0019191196145156297,
#  'away_team': 'Central Arkansas',
#  'conference_game': False,
#  'excitement_index': 2.226002,
#  'highlights': 'https://www.youtube.com/watch?v=aBwb65AoLmQ',
#  'home_conference': 'Conference USA',
#  'home_id': 5,
#  'home_line_scores': [14, 14, 3, 14],
#  'home_points': 45,
#  'home_post_win_prob': 0.9980808803854844,
#  'home_team': 'UAB',
#  'id': 401238035,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2020,
#  'season_type': 'regular',
#  'start_date': '2020-09-04T00:00:00.000Z',
#  'start_time_tbd': False,
#  'venue': 'Legion Field',
#  'venue_id': 3803,
#  'week': 1}

# %%
len(teams_2020)
# Out:
# 1697

# %%
pprint(teams_2020[207])
# Out:
# {'abbreviation': 'FLA',
#  'alt_color': '#0021a5',
#  'alt_name_1': None,
#  'alt_name_2': None,
#  'alt_name_3': None,
#  'color': '#0021A5',
#  'conference': 'SEC',
#  'division': 'East',
#  'id': 57,
#  'location': {'capacity': 88548,
#               'city': 'Gainesville',
#               'country_code': 'US',
#               'dome': False,
#               'elevation': '44.97250748',
#               'grass': True,
#               'latitude': 29.6499357,
#               'longitude': -82.3485788,
#               'name': 'Ben Hill Griffin Stadium',
#               'state': 'FL',
#               'timezone': 'America/New_York',
#               'venue_id': 3634,
#               'year_constructed': 1930,
#               'zip': '32653'},
#  'logos': ['http://a.espncdn.com/i/teamlogos/ncaa/500/57.png',
#            'http://a.espncdn.com/i/teamlogos/ncaa/500-dark/57.png'],
#  'mascot': 'Gators',
#  'school': 'Florida'}

# %%
team_df = pd.DataFrame().from_records([
        dict(
            school=team.school,
            mascot=team.mascot,
            abv=team.abbreviation,
            conference=team.conference,
            division=team.division,
            color=team.color,
            alt_color=team.alt_color,
            scool_lat=team.location['latitude'],
            school_lon=team.location['longitude'],
            t_id=team.id)
        for team in teams])
#team_df = team_df.set_index('t_id')
team_df
# Out:
#                             school     mascot   abv     conference  division  \
# 0                Abilene Christian   Wildcats   ACU           None      None
# 1                      Adams State  Grizzlies  ADST           None      None
# 2                           Adrian   Bulldogs   ADR           None      None
# 3                        Air Force    Falcons   AFA  Mountain West  Mountain
# 4                            Akron       Zips   AKR   Mid-American      East
# ...                            ...        ...   ...            ...       ...
# 1692                 Yale Freshmen       None  None           None      None
# 1693  Yale/Princeton/Harvard Grads       None  None           None      None
# 1694                           YMI       None  None           None      None
# 1695                     York YMCA       None  None           None      None
# 1696                    Yuma Field       None  None           None      None
#
#         color alt_color  scool_lat  school_lon     t_id
# 0     #4e2683   #ebebeb        NaN         NaN     2000
# 1     #000000      None        NaN         NaN     2001
# 2     #000000      None        NaN         NaN     2003
# 3     #004a7b   #ffffff  38.996970 -104.843616     2005
# 4     #00285e   #84754e  41.072553  -81.508341     2006
# ...       ...       ...        ...         ...      ...
# 1692     None      None        NaN         NaN  1000141
# 1693     None      None        NaN         NaN  1000084
# 1694     None      None        NaN         NaN  1000720
# 1695     None      None        NaN         NaN  1000197
# 1696     None      None        NaN         NaN  1000810
#
# [1697 rows x 10 columns]

# %%
recruit_team_df = recruiting_df.merge(team_df, left_on='college', right_on='school')
#recruit_team_df = recruit_team_df.set_index('p_id')
recruit_team_df
# Out:
#         p_id               name  rating  stars position              college  \
# 0          1      D.J. Williams  0.9998      5      ILB                Miami
# 1         11     Willis McGahee  0.9948      5       RB                Miami
# 2         27       Willie Dixon  0.9884      5       WR                Miami
# 3         65      Carlos Joseph  0.9759      4       OT                Miami
# 4         70        Carl Walker  0.9747      4        S                Miami
# ...      ...                ...     ...    ...      ...                  ...
# 52157  65291  Elzie Barnett Jr.  0.7667      2        S  Arkansas-Pine Bluff
# 52158  63004     Jordan Burrell  0.8399      3       CB             Davidson
# 52159  64051     Elijah Burrell  0.8098      3     DUAL             Davidson
# 52160  64342   Clarence Freeman  0.7998      3       WR             Davidson
# 52161  64682         Ryan Clark  0.7898      2     DUAL               Bryant
#
#        player_lat    player_lon state country  ...               school  \
# 0      37.9768525  -122.0335624    CA     USA  ...                Miami
# 1      25.7742658   -80.1936589    FL     USA  ...                Miami
# 2      37.9577016  -121.2907796    CA     USA  ...                Miami
# 3      25.7742658   -80.1936589    FL     USA  ...                Miami
# 4      30.3321838    -81.655651    FL     USA  ...                Miami
# ...           ...           ...   ...     ...  ...                  ...
# 52157  32.7762719   -96.7968559    TX     USA  ...  Arkansas-Pine Bluff
# 52158  36.2077351  -119.3473421    CA     USA  ...             Davidson
# 52159  36.2077351  -119.3473421    CA     USA  ...             Davidson
# 52160    32.83259  -117.2716839    CA     USA  ...             Davidson
# 52161  39.9537359   -74.1979576    NJ     USA  ...               Bryant
#
#              mascot    abv conference division    color alt_color  scool_lat  \
# 0        Hurricanes  MIAMI        ACC  Coastal  #004325   #f0f0f0  25.957967
# 1        Hurricanes  MIAMI        ACC  Coastal  #004325   #f0f0f0  25.957967
# 2        Hurricanes  MIAMI        ACC  Coastal  #004325   #f0f0f0  25.957967
# 3        Hurricanes  MIAMI        ACC  Coastal  #004325   #f0f0f0  25.957967
# 4        Hurricanes  MIAMI        ACC  Coastal  #004325   #f0f0f0  25.957967
# ...             ...    ...        ...      ...      ...       ...        ...
# 52157  Golden Lions   UAPB       None     None  #e0aa0f   #eaaa00  34.253327
# 52158      Wildcats    DAV       None     None  #000000   #e51837        NaN
# 52159      Wildcats    DAV       None     None  #000000   #e51837        NaN
# 52160      Wildcats    DAV       None     None  #000000   #e51837        NaN
# 52161      Bulldogs    BRY       None     None  #000000   #9f8343  41.924206
#
#        school_lon  t_id
# 0      -80.238860  2390
# 1      -80.238860  2390
# 2      -80.238860  2390
# 3      -80.238860  2390
# 4      -80.238860  2390
# ...           ...   ...
# 52157  -92.021403  2029
# 52158         NaN  2166
# 52159         NaN  2166
# 52160         NaN  2166
# 52161  -71.538512  2803
#
# [52162 rows x 21 columns]

# %%
recruit_team_df.head(500)
# Out:
#      p_id                name  rating  stars position  college  player_lat  \
# 0       1       D.J. Williams  0.9998      5      ILB    Miami  37.9768525
# 1      11      Willis McGahee  0.9948      5       RB    Miami  25.7742658
# 2      27        Willie Dixon  0.9884      5       WR    Miami  37.9577016
# 3      65       Carlos Joseph  0.9759      4       OT    Miami  25.7742658
# 4      70         Carl Walker  0.9747      4        S    Miami  30.3321838
# ..    ...                 ...     ...    ...      ...      ...         ...
# 495  4237    McIntosh Nicolas  0.9663      4       CB  Florida  26.4186898
# 496  4110       Mike McIntosh  0.9222      4       WR  Florida  30.3321838
# 497  4104  Derrick McPhearson  0.9157      4       WR  Florida  38.9529442
# 498  4307       Michael Brown  0.9000      4       DT  Florida  33.7490987
# 499  4131    Javier Estopinan  0.9000      4      ILB  Florida  25.7742658
#
#        player_lon state country  ...   school      mascot    abv conference  \
# 0    -122.0335624    CA     USA  ...    Miami  Hurricanes  MIAMI        ACC
# 1     -80.1936589    FL     USA  ...    Miami  Hurricanes  MIAMI        ACC
# 2    -121.2907796    CA     USA  ...    Miami  Hurricanes  MIAMI        ACC
# 3     -80.1936589    FL     USA  ...    Miami  Hurricanes  MIAMI        ACC
# 4      -81.655651    FL     USA  ...    Miami  Hurricanes  MIAMI        ACC
# ..            ...   ...     ...  ...      ...         ...    ...        ...
# 495   -81.4172993    FL     USA  ...  Florida      Gators    FLA        SEC
# 496    -81.655651    FL     USA  ...  Florida      Gators    FLA        SEC
# 497   -76.9408647    MD     USA  ...  Florida      Gators    FLA        SEC
# 498   -84.3901849    GA     USA  ...  Florida      Gators    FLA        SEC
# 499   -80.1936589    FL     USA  ...  Florida      Gators    FLA        SEC
#
#     division    color alt_color  scool_lat  school_lon  t_id
# 0    Coastal  #004325   #f0f0f0  25.957967  -80.238860  2390
# 1    Coastal  #004325   #f0f0f0  25.957967  -80.238860  2390
# 2    Coastal  #004325   #f0f0f0  25.957967  -80.238860  2390
# 3    Coastal  #004325   #f0f0f0  25.957967  -80.238860  2390
# 4    Coastal  #004325   #f0f0f0  25.957967  -80.238860  2390
# ..       ...      ...       ...        ...         ...   ...
# 495     East  #0021A5   #0021a5  29.649936  -82.348579    57
# 496     East  #0021A5   #0021a5  29.649936  -82.348579    57
# 497     East  #0021A5   #0021a5  29.649936  -82.348579    57
# 498     East  #0021A5   #0021a5  29.649936  -82.348579    57
# 499     East  #0021A5   #0021a5  29.649936  -82.348579    57
#
# [500 rows x 21 columns]

# %%
# Export file as a CSV, without the Pandas index, but with the header
recruit_team_df.to_csv("recruiting_db.csv", header=True)

# %%
recruit_team_df.to_json('recruit_team.json', orient = 'records')
